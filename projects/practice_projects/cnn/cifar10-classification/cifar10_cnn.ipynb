# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
(x_trainbk, y_trainbk, x_testbk, y_testbk) = (x_train, y_train, x_test, y_test)

# %%
(x_train, y_train, x_test, y_test) = (x_trainbk, y_trainbk, x_testbk, y_testbk)

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
x_train[1][0][0]
# Out:
# array([154, 177, 187], dtype=uint8)

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
x_train[1][0][0]
# Out:
# array([0.6039216 , 0.69411767, 0.73333335], dtype=float32)

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 20s - loss: 1.6020 - acc: 0.4198 - val_loss: 1.6135 - val_acc: 0.4548
#
# Epoch 00001: val_loss improved from inf to 1.61350, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 19s - loss: 1.2671 - acc: 0.5497 - val_loss: 1.2509 - val_acc: 0.5384
#
# Epoch 00002: val_loss improved from 1.61350 to 1.25091, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 19s - loss: 1.1437 - acc: 0.5952 - val_loss: 1.0760 - val_acc: 0.6200
#
# Epoch 00003: val_loss improved from 1.25091 to 1.07601, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 20s - loss: 1.0820 - acc: 0.6206 - val_loss: 1.2522 - val_acc: 0.5540
#
# Epoch 00004: val_loss did not improve from 1.07601
# Epoch 5/100
#  - 20s - loss: 1.0397 - acc: 0.6359 - val_loss: 0.9805 - val_acc: 0.6670
#
# Epoch 00005: val_loss improved from 1.07601 to 0.98049, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 18s - loss: 1.0152 - acc: 0.6469 - val_loss: 1.0728 - val_acc: 0.6404
#
# Epoch 00006: val_loss did not improve from 0.98049
# Epoch 7/100
#  - 20s - loss: 1.0042 - acc: 0.6548 - val_loss: 0.9936 - val_acc: 0.6582
#
# Epoch 00007: val_loss did not improve from 0.98049
# Epoch 8/100
#  - 20s - loss: 0.9906 - acc: 0.6584 - val_loss: 1.1672 - val_acc: 0.6360
#
# Epoch 00008: val_loss did not improve from 0.98049
# Epoch 9/100
#  - 21s - loss: 0.9918 - acc: 0.6611 - val_loss: 1.4212 - val_acc: 0.5646
#
# Epoch 00009: val_loss did not improve from 0.98049
# Epoch 10/100
#  - 24s - loss: 0.9973 - acc: 0.6628 - val_loss: 0.9577 - val_acc: 0.6710
#
# Epoch 00010: val_loss improved from 0.98049 to 0.95765, saving model to model.weights.best.hdf5
# Epoch 11/100
#  - 24s - loss: 1.0020 - acc: 0.6622 - val_loss: 1.0587 - val_acc: 0.6710
#
# Epoch 00011: val_loss did not improve from 0.95765
# Epoch 12/100
#  - 24s - loss: 1.0076 - acc: 0.6621 - val_loss: 0.9876 - val_acc: 0.6776
#
# Epoch 00012: val_loss did not improve from 0.95765
# Epoch 13/100
#  - 24s - loss: 1.0328 - acc: 0.6529 - val_loss: 1.0079 - val_acc: 0.6604
#
# Epoch 00013: val_loss did not improve from 0.95765
# Epoch 14/100
#  - 24s - loss: 1.0464 - acc: 0.6496 - val_loss: 1.0802 - val_acc: 0.6326
#
# Epoch 00014: val_loss did not improve from 0.95765
# Epoch 15/100
#  - 24s - loss: 1.0616 - acc: 0.6455 - val_loss: 0.9881 - val_acc: 0.6698
#
# Epoch 00015: val_loss did not improve from 0.95765
# Epoch 16/100
#  - 24s - loss: 1.0782 - acc: 0.6422 - val_loss: 1.7056 - val_acc: 0.5906
#
# Epoch 00016: val_loss did not improve from 0.95765
# Epoch 17/100
#  - 23s - loss: 1.1030 - acc: 0.6358 - val_loss: 1.0189 - val_acc: 0.6666
#
# Epoch 00017: val_loss did not improve from 0.95765
# Epoch 18/100
#  - 24s - loss: 1.1112 - acc: 0.6314 - val_loss: 1.9939 - val_acc: 0.5432
#
# Epoch 00018: val_loss did not improve from 0.95765
# Epoch 19/100
#  - 24s - loss: 1.1235 - acc: 0.6277 - val_loss: 1.3257 - val_acc: 0.5306
#
# Epoch 00019: val_loss did not improve from 0.95765
# Epoch 20/100
#  - 24s - loss: 1.1444 - acc: 0.6228 - val_loss: 1.2495 - val_acc: 0.5848
#
# Epoch 00020: val_loss did not improve from 0.95765
# Epoch 21/100
#  - 24s - loss: 1.1639 - acc: 0.6202 - val_loss: 1.5394 - val_acc: 0.6144
#
# Epoch 00021: val_loss did not improve from 0.95765
# Epoch 22/100
#  - 24s - loss: 1.1844 - acc: 0.6105 - val_loss: 1.6059 - val_acc: 0.5980
#
# Epoch 00022: val_loss did not improve from 0.95765
# Epoch 23/100
#  - 25s - loss: 1.2110 - acc: 0.6008 - val_loss: 1.1350 - val_acc: 0.6266
#
# Epoch 00023: val_loss did not improve from 0.95765
# Epoch 24/100
#  - 24s - loss: 1.2039 - acc: 0.6013 - val_loss: 1.0129 - val_acc: 0.6610
#
# Epoch 00024: val_loss did not improve from 0.95765
# Epoch 25/100
#  - 24s - loss: 1.2208 - acc: 0.5962 - val_loss: 1.1428 - val_acc: 0.6188
#
# Epoch 00025: val_loss did not improve from 0.95765
# Epoch 26/100
#  - 24s - loss: 1.2382 - acc: 0.5933 - val_loss: 1.1421 - val_acc: 0.6300
#
# Epoch 00026: val_loss did not improve from 0.95765
# Epoch 27/100
#  - 24s - loss: 1.2473 - acc: 0.5898 - val_loss: 1.1008 - val_acc: 0.6316
#
# Epoch 00027: val_loss did not improve from 0.95765
# Epoch 28/100
#  - 24s - loss: 1.2522 - acc: 0.5844 - val_loss: 1.0133 - val_acc: 0.6576
#
# Epoch 00028: val_loss did not improve from 0.95765
# Epoch 29/100
#  - 26s - loss: 1.2764 - acc: 0.5775 - val_loss: 1.1207 - val_acc: 0.6240
#
# Epoch 00029: val_loss did not improve from 0.95765
# Epoch 30/100
#  - 27s - loss: 1.2856 - acc: 0.5758 - val_loss: 1.3780 - val_acc: 0.5612
#
# Epoch 00030: val_loss did not improve from 0.95765
# Epoch 31/100
#  - 28s - loss: 1.2862 - acc: 0.5750 - val_loss: 1.4459 - val_acc: 0.6032
#
# Epoch 00031: val_loss did not improve from 0.95765
# Epoch 32/100
#  - 24s - loss: 1.2953 - acc: 0.5717 - val_loss: 1.0976 - val_acc: 0.6286
#
# Epoch 00032: val_loss did not improve from 0.95765
# Epoch 33/100
#  - 20s - loss: 1.3088 - acc: 0.5666 - val_loss: 1.2836 - val_acc: 0.5730
#
# Epoch 00033: val_loss did not improve from 0.95765
# Epoch 34/100
#  - 20s - loss: 1.3225 - acc: 0.5632 - val_loss: 1.4723 - val_acc: 0.5118
#
# Epoch 00034: val_loss did not improve from 0.95765
# Epoch 35/100
#  - 20s - loss: 1.3531 - acc: 0.5585 - val_loss: 1.5335 - val_acc: 0.5118
#
# Epoch 00035: val_loss did not improve from 0.95765
# Epoch 36/100
#  - 21s - loss: 1.3401 - acc: 0.5567 - val_loss: 1.1078 - val_acc: 0.6256
#
# Epoch 00036: val_loss did not improve from 0.95765
# Epoch 37/100
#  - 18s - loss: 1.3587 - acc: 0.5529 - val_loss: 3.5311 - val_acc: 0.4934
#
# Epoch 00037: val_loss did not improve from 0.95765
# Epoch 38/100
#  - 19s - loss: 1.3629 - acc: 0.5487 - val_loss: 1.0975 - val_acc: 0.6218
#
# Epoch 00038: val_loss did not improve from 0.95765
# Epoch 39/100
#  - 21s - loss: 1.3796 - acc: 0.5436 - val_loss: 1.6689 - val_acc: 0.5128
#
# Epoch 00039: val_loss did not improve from 0.95765
# Epoch 40/100
#  - 24s - loss: 1.3841 - acc: 0.5369 - val_loss: 1.3223 - val_acc: 0.6094
#
# Epoch 00040: val_loss did not improve from 0.95765
# Epoch 41/100
#  - 23s - loss: 1.3937 - acc: 0.5378 - val_loss: 1.1503 - val_acc: 0.6024
#
# Epoch 00041: val_loss did not improve from 0.95765
# Epoch 42/100
#  - 22s - loss: 1.3897 - acc: 0.5380 - val_loss: 1.6358 - val_acc: 0.5652
#
# Epoch 00042: val_loss did not improve from 0.95765
# Epoch 43/100
#  - 20s - loss: 1.4065 - acc: 0.5330 - val_loss: 3.0662 - val_acc: 0.3560
#
# Epoch 00043: val_loss did not improve from 0.95765
# Epoch 44/100
#  - 21s - loss: 1.4263 - acc: 0.5267 - val_loss: 1.2168 - val_acc: 0.6044
#
# Epoch 00044: val_loss did not improve from 0.95765
# Epoch 45/100
#  - 21s - loss: 1.4376 - acc: 0.5215 - val_loss: 1.3315 - val_acc: 0.5550
#
# Epoch 00045: val_loss did not improve from 0.95765
# Epoch 46/100
#  - 21s - loss: 1.4440 - acc: 0.5228 - val_loss: 1.4836 - val_acc: 0.5424
#
# Epoch 00046: val_loss did not improve from 0.95765
# Epoch 47/100
#  - 22s - loss: 1.4577 - acc: 0.5175 - val_loss: 2.8677 - val_acc: 0.4336
#
# Epoch 00047: val_loss did not improve from 0.95765
# Epoch 48/100
#  - 21s - loss: 1.4687 - acc: 0.5124 - val_loss: 1.4645 - val_acc: 0.5428
#
# Epoch 00048: val_loss did not improve from 0.95765
# Epoch 49/100
#  - 22s - loss: 1.4953 - acc: 0.5055 - val_loss: 1.4386 - val_acc: 0.5290
#
# Epoch 00049: val_loss did not improve from 0.95765
# Epoch 50/100
#  - 22s - loss: 1.5020 - acc: 0.5014 - val_loss: 1.9415 - val_acc: 0.4964
#
# Epoch 00050: val_loss did not improve from 0.95765
# Epoch 51/100
#  - 23s - loss: 1.5085 - acc: 0.5001 - val_loss: 1.4248 - val_acc: 0.5182
#
# Epoch 00051: val_loss did not improve from 0.95765
# Epoch 52/100
#  - 22s - loss: 1.5213 - acc: 0.4959 - val_loss: 1.1857 - val_acc: 0.5946
#
# Epoch 00052: val_loss did not improve from 0.95765
# Epoch 53/100
#  - 22s - loss: 1.5136 - acc: 0.4915 - val_loss: 1.6045 - val_acc: 0.4258
#
# Epoch 00053: val_loss did not improve from 0.95765
# Epoch 54/100
#  - 22s - loss: 1.5321 - acc: 0.4871 - val_loss: 1.3413 - val_acc: 0.5204
#
# Epoch 00054: val_loss did not improve from 0.95765
# Epoch 55/100
#  - 22s - loss: 1.5426 - acc: 0.4832 - val_loss: 1.4616 - val_acc: 0.5206
#
# Epoch 00055: val_loss did not improve from 0.95765
# Epoch 56/100
#  - 22s - loss: 1.5402 - acc: 0.4839 - val_loss: 1.4411 - val_acc: 0.5226
#
# Epoch 00056: val_loss did not improve from 0.95765
# Epoch 57/100
#  - 22s - loss: 1.5400 - acc: 0.4862 - val_loss: 1.1672 - val_acc: 0.6006
#
# Epoch 00057: val_loss did not improve from 0.95765
# Epoch 58/100
#  - 27s - loss: 1.5705 - acc: 0.4714 - val_loss: 2.2797 - val_acc: 0.4528
# Epoch 00058: val_loss did not improve from 0.95765
# Epoch 59/100
#  - 20s - loss: 1.5865 - acc: 0.4670 - val_loss: 1.7496 - val_acc: 0.4402
#
# Epoch 00059: val_loss did not improve from 0.95765
# Epoch 60/100
#  - 20s - loss: 1.6145 - acc: 0.4627 - val_loss: 1.3292 - val_acc: 0.5386
#
# Epoch 00060: val_loss did not improve from 0.95765
# Epoch 61/100
#  - 20s - loss: 1.6038 - acc: 0.4595 - val_loss: 1.5711 - val_acc: 0.4836
#
# Epoch 00061: val_loss did not improve from 0.95765
# Epoch 62/100
#  - 20s - loss: 1.6509 - acc: 0.4484 - val_loss: 1.7992 - val_acc: 0.3590
#
# Epoch 00062: val_loss did not improve from 0.95765
# Epoch 63/100
#  - 20s - loss: 1.6415 - acc: 0.4447 - val_loss: 1.4722 - val_acc: 0.4738
#
# Epoch 00063: val_loss did not improve from 0.95765
# Epoch 64/100
#  - 20s - loss: 1.6586 - acc: 0.4431 - val_loss: 2.7107 - val_acc: 0.3618
#
# Epoch 00064: val_loss did not improve from 0.95765
# Epoch 65/100
#  - 20s - loss: 1.6763 - acc: 0.4295 - val_loss: 1.4917 - val_acc: 0.5068
#
# Epoch 00065: val_loss did not improve from 0.95765
# Epoch 66/100
#  - 21s - loss: 1.7066 - acc: 0.4203 - val_loss: 1.6185 - val_acc: 0.4328
#
# Epoch 00066: val_loss did not improve from 0.95765
# Epoch 67/100
#  - 20s - loss: 1.7483 - acc: 0.4071 - val_loss: 2.2201 - val_acc: 0.3620
#
# Epoch 00067: val_loss did not improve from 0.95765
# Epoch 68/100
#  - 20s - loss: 1.7562 - acc: 0.4047 - val_loss: 1.6684 - val_acc: 0.4182
#
# Epoch 00068: val_loss did not improve from 0.95765
# Epoch 69/100
#  - 21s - loss: 1.7764 - acc: 0.3949 - val_loss: 1.6322 - val_acc: 0.4276
#
# Epoch 00069: val_loss did not improve from 0.95765
# Epoch 70/100
#  - 21s - loss: 1.8047 - acc: 0.3895 - val_loss: 2.4573 - val_acc: 0.3344
#
# Epoch 00070: val_loss did not improve from 0.95765
# Epoch 71/100
#  - 20s - loss: 1.8236 - acc: 0.3758 - val_loss: 1.8297 - val_acc: 0.3972
#
# Epoch 00071: val_loss did not improve from 0.95765
# Epoch 72/100
#  - 20s - loss: 1.8395 - acc: 0.3675 - val_loss: 1.7621 - val_acc: 0.3742
#
# Epoch 00072: val_loss did not improve from 0.95765
# Epoch 73/100
#  - 20s - loss: 1.8357 - acc: 0.3629 - val_loss: 1.9545 - val_acc: 0.4172
#
# Epoch 00073: val_loss did not improve from 0.95765
# Epoch 74/100
#  - 20s - loss: 1.8389 - acc: 0.3591 - val_loss: 1.7960 - val_acc: 0.3634
#
# Epoch 00074: val_loss did not improve from 0.95765
# Epoch 75/100
#  - 23s - loss: 1.8429 - acc: 0.3496 - val_loss: 1.7394 - val_acc: 0.3782
#
# Epoch 00075: val_loss did not improve from 0.95765
# Epoch 76/100
#  - 23s - loss: 1.8561 - acc: 0.3475 - val_loss: 1.7660 - val_acc: 0.3388
#
# Epoch 00076: val_loss did not improve from 0.95765
# Epoch 77/100
#  - 23s - loss: 1.8700 - acc: 0.3407 - val_loss: 1.6513 - val_acc: 0.3984
#
# Epoch 00077: val_loss did not improve from 0.95765
# Epoch 78/100
#  - 23s - loss: 1.8751 - acc: 0.3323 - val_loss: 1.7090 - val_acc: 0.3802
#
# Epoch 00078: val_loss did not improve from 0.95765
# Epoch 79/100
#  - 23s - loss: 1.8607 - acc: 0.3369 - val_loss: 1.7277 - val_acc: 0.3840
#
# Epoch 00079: val_loss did not improve from 0.95765
# Epoch 80/100
#  - 22s - loss: 1.8800 - acc: 0.3234 - val_loss: 2.3769 - val_acc: 0.1954
#
# Epoch 00080: val_loss did not improve from 0.95765
# Epoch 81/100
#  - 22s - loss: 1.8679 - acc: 0.3186 - val_loss: 1.7729 - val_acc: 0.3698
#
# Epoch 00081: val_loss did not improve from 0.95765
# Epoch 82/100
#  - 23s - loss: 1.8638 - acc: 0.3225 - val_loss: 1.8189 - val_acc: 0.3280
#
# Epoch 00082: val_loss did not improve from 0.95765
# Epoch 83/100
#  - 23s - loss: 1.8536 - acc: 0.3289 - val_loss: 1.9980 - val_acc: 0.2860
#
# Epoch 00083: val_loss did not improve from 0.95765
# Epoch 84/100
#  - 22s - loss: 1.8485 - acc: 0.3245 - val_loss: 1.7198 - val_acc: 0.3852
#
# Epoch 00084: val_loss did not improve from 0.95765
# Epoch 85/100
#  - 22s - loss: 1.8476 - acc: 0.3292 - val_loss: 1.7407 - val_acc: 0.3578
#
# Epoch 00085: val_loss did not improve from 0.95765
# Epoch 86/100
#  - 21s - loss: 1.8355 - acc: 0.3270 - val_loss: 1.8109 - val_acc: 0.3192
#
# Epoch 00086: val_loss did not improve from 0.95765
# Epoch 87/100
#  - 20s - loss: 1.8416 - acc: 0.3298 - val_loss: 1.7920 - val_acc: 0.3290
#
# Epoch 00087: val_loss did not improve from 0.95765
# Epoch 88/100
#  - 20s - loss: 1.8354 - acc: 0.3328 - val_loss: 1.7432 - val_acc: 0.3564
#
# Epoch 00088: val_loss did not improve from 0.95765
# Epoch 89/100
#  - 20s - loss: 1.8268 - acc: 0.3286 - val_loss: 1.6947 - val_acc: 0.3674
#
# Epoch 00089: val_loss did not improve from 0.95765
# Epoch 90/100
#  - 20s - loss: 1.8254 - acc: 0.3278 - val_loss: 1.6811 - val_acc: 0.3872
#
# Epoch 00090: val_loss did not improve from 0.95765
# Epoch 91/100
#  - 22s - loss: 1.8229 - acc: 0.3300 - val_loss: 1.6967 - val_acc: 0.3690
#
# Epoch 00091: val_loss did not improve from 0.95765
# Epoch 92/100
#  - 20s - loss: 1.8199 - acc: 0.3314 - val_loss: 1.7829 - val_acc: 0.3332
#
# Epoch 00092: val_loss did not improve from 0.95765
# Epoch 93/100
#  - 21s - loss: 1.8227 - acc: 0.3278 - val_loss: 1.9458 - val_acc: 0.2946
#
# Epoch 00093: val_loss did not improve from 0.95765
# Epoch 94/100
#  - 23s - loss: 1.8143 - acc: 0.3303 - val_loss: 1.6570 - val_acc: 0.3952
#
# Epoch 00094: val_loss did not improve from 0.95765
# Epoch 95/100
#  - 22s - loss: 1.8103 - acc: 0.3313 - val_loss: 1.6403 - val_acc: 0.3806
#
# Epoch 00095: val_loss did not improve from 0.95765
# Epoch 96/100
#  - 23s - loss: 1.8091 - acc: 0.3341 - val_loss: 1.7932 - val_acc: 0.3294
#
# Epoch 00096: val_loss did not improve from 0.95765
# Epoch 97/100
#  - 22s - loss: 1.8107 - acc: 0.3311 - val_loss: 1.6891 - val_acc: 0.3692
#
# Epoch 00097: val_loss did not improve from 0.95765
# Epoch 98/100
#  - 23s - loss: 1.8098 - acc: 0.3343 - val_loss: 1.7155 - val_acc: 0.3694
#
# Epoch 00098: val_loss did not improve from 0.95765
# Epoch 99/100
#  - 23s - loss: 1.8115 - acc: 0.3297 - val_loss: 1.7994 - val_acc: 0.3436
#
# Epoch 00099: val_loss did not improve from 0.95765
# Epoch 100/100
#  - 22s - loss: 1.8100 - acc: 0.3334 - val_loss: 1.8216 - val_acc: 0.3258
#
# Epoch 00100: val_loss did not improve from 0.95765

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6659

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
